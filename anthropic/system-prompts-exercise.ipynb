# %%
#Load env variable
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content":text}
    messages.append(assistant_message)    


def chat(messages, system_prompt=None):

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system_prompt:
        params["system"] = system_prompt
    
    #MAke a request
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system_prompt = """
    Write very concise code
    """
add_user_message(messages,'Write a Python function that checks a string for duplicate characters.')

answer = chat(messages,system_prompt)

answer
# Out:
# '# Simple and concise ways to check for duplicate characters:\n\n```python\n# Method 1: Using set (most concise)\ndef has_duplicates(s):\n    return len(s) != len(set(s))\n\n# Method 2: Using set with any()\ndef has_duplicates(s):\n    return any(s.count(c) > 1 for c in set(s))\n\n# Method 3: Using dict/Counter\nfrom collections import Counter\n\ndef has_duplicates(s):\n    return any(v > 1 for v in Counter(s).values())\n\n# Method 4: Early return (efficient for long strings)\ndef has_duplicates(s):\n    seen = set()\n    for c in s:\n        if c in seen:\n            return True\n        seen.add(c)\n    return False\n```\n\n**Examples:**\n```python\nprint(has_duplicates("hello"))      # True (l appears twice)\nprint(has_duplicates("python"))     # False\nprint(has_duplicates("aabbcc"))     # True\nprint(has_duplicates("abc"))        # False\n```\n\n**Performance comparison:**\n- **Method 1** (set): O(n) time, O(n) space - **fastest & simplest**\n- **Method 4** (early return): O(n) time, O(n) space - **best for early detection**\n\nUse **Method 1** for most cases—it\'s concise and efficient!'
