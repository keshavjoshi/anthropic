# %%
#Load env variable
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content":text}
    messages.append(assistant_message)    


def chat(messages, system_prompt=None):

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system_prompt:
        params["system"] = system_prompt
    
    #MAke a request
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system_prompt = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """
add_user_message(messages,'How to solve 5X+3=2 for x?')

answer = chat(messages,system_prompt)

answer
# Out:
# "# Let's work through this step-by-step!\n\n**Step 1:** What is your goal here?\n- You want to get X by itself on one side of the equation, right?\n\n**Step 2:** Look at what's happening to X:\n- You have `5X + 3 = 2`\n- X is being multiplied by 5, AND you're adding 3 to it\n- Which operation should you undo first—the multiplication or the addition?\n\n**Hint:** Think about the order of operations in reverse. We usually multiply before we add, so to undo it, we should undo the addition first.\n\n**Step 3:** What number would you subtract from both sides to remove the +3?\n\nOnce you answer that, let me know what you get, and we'll move to the next step! 😊"
